# %% [markdown]
# Import necessary Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Reading the input dataSet

# %%
df = pd.read_csv('coupons_ner.csv')

# %%
df.shape
# Out:
# (885, 1)

# %%
df.head(4)
# Out:
#   Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld or larger (includes Downy Odor Protect 48 oz or larger OR Downy Wrinkle Guard 40 oz or larger OR Downy Nature Blends 67 oz or larger) OR Bounce/Downy Sheets 130 ct or larger (includes Bounce/Downy Wrinkle Guard 80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes Downy Unstopables, Fresh Protect, Odor Protect, and Infusions) (excludes Downy Libre Enjuague, Gain Fireworks, and trial/travel size).
# 0  Save $2.00 ONE Tide PODS OR Tide Power PODS (e...
# 1  Save $2.00 ONE Tide Laundry Detergent (exclude...
# 2  SAVE $1.00 ON TWO when you buy TWO BOXES (8.9 ...
# 3  $3.00 OFF when you purchase any THREE (3) Pepp...

# %% [markdown]
# All the offer data in present in single columns

# %% [markdown]
# ### Excercise 1
# #### Write a function that takes OfferDetails as input, and returns FaceValue as output

# %%
def get_FaceValue(string_S):                    # Taking  String as Input 
    for x in (string_S.split()):                # Spliting the string by ' ' space between each wrods
        if ('$' in x) or ('¢'in x):             # Finding the block which contain dollar or cent symbol 
            return x                            # Return the Fave Value

# %%
# Check the function functionality 
print(get_FaceValue(df[:1].to_string()))
# Out:
# $2.00

# %%
# Run Function for every row
for x in range(0,df.size+1):
    print(get_FaceValue(df[:x].to_string()))
# Out:
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# $2.00
# ...
