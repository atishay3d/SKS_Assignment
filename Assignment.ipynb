# %% [markdown]
# Import necessary Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Reading the input dataSet

# %%
df = pd.read_csv('coupons_ner.csv',header=None)

# %%
df.shape
# Out:
# (886, 1)

# %%
pd.set_option('display.max_colwidth', -1)
#df.reset_index(drop=True, inplace=True)

# %%
df.head(132)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0
# 0    Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld or larger (includes Downy Odor Protect 48 oz or larger OR Downy Wrinkle Guard 40 oz or larger OR Downy Nature Blends 67 oz or larger) OR Bounce/Downy Sheets 130 ct or larger (includes Bounce/Downy Wrinkle Guard 80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes Downy Unstopables, Fresh Protect, Odor Protect, and Infusions) (excludes Downy Libre Enjuague, Gain Fireworks, and trial/travel size).
# ...

# %% [markdown]
# All the offer data in present in single columns

# %% [markdown]
# ### Excercise 1
# #### Write a function that takes OfferDetails as input, and returns FaceValue as output

# %%
def get_FaceValue(string_S):   
    y = 'NO _Valu'
    if re.findall('¢',string_S) or re.findall('\$',string_S): # Finding the element which contain dollar or cent symbol 
        for x in string_S.split():
            if ('$' in x) or ('¢'in x): 
                return x
    else:
        return 'No Face Value' # Return the Fave Value

# %%
# Check the function functionality 
print(get_FaceValue(df[5:6].to_string()))
print(get_FaceValue(df[131:132].to_string()))
# Out:
# $1.11
# No Face Value

# %% [markdown]
# #### Run the function against all rows in the attached data and determine function accuracy (Higher the better)

# %%
for x in range(1,df.size+1):
    get_FaceValue(df[:x].to_string())
    print(x,get_FaceValue(df[x-1:x].to_string()))
# Out:
# 1 $2.00
# 2 $2.00
# 3 $2.00
# 4 $1.00
# 5 $3.00
# 6 $1.11
# 7 $1.00
# 8 $1.00
# 9 $0.65
# 10 $2.00
# 11 $0.50
# 12 $1.00
# 13 $0.50
# 14 $0.50
# 15 $1.00
# 16 $1.00
# 17 $1.00
# 18 $0.50
# 19 $2.00
# 20 $0.50
# 21 $1.00
# 22 $1.25
# 23 $2.00
# 24 $1.00
# 25 $1.00
# 26 $1.00
# 27 $1.00
# 28 $1.00
# 29 $1.00
# 30 $1.00
# 31 $1.00
# 32 $1.00
# 33 $0.75
# 34 $1.00
# 35 $3.00
# 36 $2.00
# 37 $4.00
# 38 $2.00
# 39 55¢
# 40 $1.50
# 41 $4.00
# 42 $3.00
# 43 $2.00
# 44 $4.00
# 45 $2.00
# 46 $2.00
# 47 $2.00
# 48 $5.00
# 49 $2.00
# 50 $3.00
# 51 $2.00
# 52 $2.00
# 53 $1.50
# 54 $1.50
# 55 $2.00
# 56 $3.00
# 57 $3.00
# 58 $2.00
# 59 $1.00
# 60 $8.00
# 61 $3.00
# 62 $0.75
# 63 $1.50
# 64 $3.00
# 65 55¢
# 66 $5.00
# 67 $3.00
# 68 $0.75
# 69 $3.00
# 70 $1.00
# 71 $5.00
# 72 $5.00
# 73 $4.00
# 74 $1.00
# 75 $4.00
# 76 $1.00
# 77 $2.00
# 78 $0.75
# 79 $4.00
# 80 $3.00
# 81 $2.00
# 82 $5
# 83 $1.00
# 84 $0.50
# 85 $1.50)
# 86 $1.00
# 87 $1.00
# 88 $2.00
# 89 $2.00
# 90 $1.00
# 91 $2.00
# 92 $0.50
# ...

# %% [markdown]
# ### Excercise 2
# #### Write a function that takes OfferDetails as input, and returns Product as output (Product can be single or array)

# %%
import re
#print(df.iloc[1,[-1]])
print(df.iloc[1,[-1]].to_string())
res = re.split(' Or | OR | or | and | AND | And ',df.iloc[0,[-1]].to_string())
print(res)



#x = re.search("\$", res)

#print("The first white-space character is located in position:", x.start())
#(df[5:6].to_string()).split('or')
# Out:
# 0    Save $2.00 ONE Tide PODS OR Tide Power PODS (excludes Tide Liquid/Powder Laundry Detergent, Tide Simply, Tide Simply PODS, and Tide PODS 9 ct and below, and trial/travel size).
# ['0    Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld', 'larger (includes Downy Odor Protect 48 oz', 'larger', 'Downy Wrinkle Guard 40 oz', 'larger', 'Downy Nature Blends 67 oz', 'larger)', 'Bounce/Downy Sheets 130 ct', 'larger (includes Bounce/Downy Wrinkle Guard 80 ct', 'larger)', 'In Wash Scent Boosters 8.6 oz', 'larger (includes Downy Unstopables, Fresh Protect, Odor Protect,', 'Infusions) (excludes Downy Libre Enjuague, Gain Fireworks,', 'trial/travel size).']

# %%
str1 = 'SAVE $1.11 when you buy any ONE (1) Familly Size OREO, CHIPS AHOY! or NUTTER BUTTER Cookies (12.1 - 20 oz.)'
print(str1)
# Out:
# SAVE $1.11 when you buy any ONE (1) Familly Size OREO, CHIPS AHOY! or NUTTER BUTTER Cookies (12.1 - 20 oz.)

# %%
import re

txt = "The rain in Spain"
x = re.search("\s", txt)

print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3

# %%
def get_ProductName(string_S):                    
    for x in (string_S.split('OR')):               
        if ('$' in x) or ('¢'in x):             
            return x

# %%
for x in range(0,df.size+1):
    if get_FaceValue(df[:x].to_string()):
        print(get_FaceValue(df[x:x+1].to_string()))
    else:
        print('No Value')
# Out:
# No Value
# $2.00
# $2.00
# $1.00
# $3.00
# $1.11
# $1.00
# $1.00
# $0.65
# $2.00
# $0.50
# $1.00
# $0.50
# $0.50
# $1.00
# $1.00
# $1.00
# $0.50
# $2.00
# $0.50
# $1.00
# $1.25
# $2.00
# $1.00
# $1.00
# $1.00
# $1.00
# $1.00
# $1.00
# $1.00
# $1.00
# $1.00
# $0.75
# $1.00
# $3.00
# $2.00
# $4.00
# $2.00
# 55¢
# $1.50
# $4.00
# $3.00
# $2.00
# $4.00
# $2.00
# $2.00
# $2.00
# $5.00
# $2.00
# $3.00
# $2.00
# $2.00
# $1.50
# $1.50
# $2.00
# $3.00
# $3.00
# $2.00
# $1.00
# $8.00
# $3.00
# $0.75
# $1.50
# $3.00
# 55¢
# $5.00
# $3.00
# $0.75
# $3.00
# $1.00
# $5.00
# $5.00
# $4.00
# $1.00
# $4.00
# $1.00
# $2.00
# $0.75
# $4.00
# $3.00
# $2.00
# $5
# $1.00
# $0.50
# $1.50)
# $1.00
# $1.00
# $2.00
# $2.00
# $1.00
# $2.00
# $0.50
# $0.50
# $0.50
# $1.00
# $2.00
# $2.00
# $1.50
# $1.00
# $2.00
# $2.00
# $1.00
# $1.25
# $1.00
# $1.00
# $0.50
# $0.25
# $1.00
# $1.00
# $2.00
# $1.00
# $1.00
# $2.00
# $3.00
# $0.50
# $2.00
# $1.00
# $1.00
# 55¢
# $3.00
# $2.00
# $1.00
# $4.00
# $2.00
# $3.00
# ...

# %%
for ent in doc.ents: 
    if ent.label_ in {'ORG','LOC','WORK_OF_ART'} :
        print( ent.text)
# Out:
# Downy Liquid Fabric
# Downy Odor Protect
# Downy Wrinkle Guard 40
# Downy Nature Blends
# Downy Unstopables
# Odor Protect
# Downy Libre

# %%
print(str1)
# Out:
# SAVE $1.11 when you buy any ONE (1) Familly Size OREO, CHIPS AHOY! or NUTTER BUTTER Cookies (12.1 - 20 oz.)

# %%
str2 = 'Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld or larger (includes Downy Odor Protect 48 oz or larger OR Downy Wrinkle Guard 40 oz or larger OR Downy Nature Blends 67 oz or larger) OR Bounce/Downy Sheets 130 ct or larger (includes Bounce/Downy Wrinkle Guard 80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes Downy Unstopables, Fresh Protect, Odor Protect, and Infusions) (excludes Downy Libre Enjuague, Gain Fireworks, and trial/travel size).'

# %%
print(str2)
# Out:
# Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld or larger (includes Downy Odor Protect 48 oz or larger OR Downy Wrinkle Guard 40 oz or larger OR Downy Nature Blends 67 oz or larger) OR Bounce/Downy Sheets 130 ct or larger (includes Bounce/Downy Wrinkle Guard 80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes Downy Unstopables, Fresh Protect, Odor Protect, and Infusions) (excludes Downy Libre Enjuague, Gain Fireworks, and trial/travel size).

# %%
import spacy 
  
nlp = spacy.load('en_core_web_sm') 
  
doc = nlp(str2) 
  
for ent in doc.ents: 
    
    print(ent.label_, ' | ', ent.text)

#help(ent)
# Out:
# MONEY  |  2.00
# ORG  |  Downy Liquid Fabric
# DATE  |  72
# LOC  |  Downy Odor Protect
# DATE  |  48
# WORK_OF_ART  |  Downy Wrinkle Guard 40
# WORK_OF_ART  |  Downy Nature Blends
# DATE  |  67
# EVENT  |  Bounce/Downy Wrinkle Guard 80
# ORG  |  Downy Unstopables
# PERSON  |  Fresh Protect
# WORK_OF_ART  |  Odor Protect
# ORG  |  Downy Libre
# PERSON  |  Gain Fireworks

# %%
[e for e in ent.doc]
# Out:
# [Save,
#  $,
#  2.00,
#  ONE,
#  Downy,
#  Liquid,
#  Fabric,
#  Conditioner,
#  72,
#  ld,
#  or,
#  larger,
#  (,
#  includes,
#  Downy,
#  Odor,
#  Protect,
#  48,
#  oz,
#  or,
#  larger,
#  OR,
#  Downy,
#  Wrinkle,
#  Guard,
#  40,
#  oz,
#  or,
#  larger,
#  OR,
#  Downy,
#  Nature,
#  Blends,
#  67,
#  oz,
#  or,
#  larger,
#  ),
#  OR,
#  Bounce,
#  /,
#  Downy,
#  Sheets,
#  130,
#  ct,
#  or,
#  larger,
#  (,
#  includes,
#  Bounce,
#  /,
#  Downy,
#  Wrinkle,
#  Guard,
#  80,
#  ct,
#  or,
#  larger,
#  ),
#  OR,
#  In,
#  Wash,
#  Scent,
#  Boosters,
#  8.6,
#  oz,
#  or,
#  larger,
#  (,
#  includes,
#  Downy,
#  Unstopables,
#  ,,
#  Fresh,
#  Protect,
#  ,,
#  Odor,
#  Protect,
#  ,,
#  and,
#  Infusions,
#  ),
#  (,
#  excludes,
#  Downy,
#  Libre,
#  Enjuague,
#  ,,
#  Gain,
#  Fireworks,
#  ,,
#  and,
#  trial,
#  /,
#  travel,
#  size,
#  ),
#  .]

# %%
help(displacy.render)
# Out:
# Help on function render in module spacy.displacy:
#
# render(docs, style='dep', page=False, minify=False, jupyter=None, options={}, manual=False)
#     Render displaCy visualisation.
#
#     docs (list or Doc): Document(s) to visualise.
#     style (unicode): Visualisation style, 'dep' or 'ent'.
#     page (bool): Render markup as full HTML page.
#     minify (bool): Minify HTML markup.
#     jupyter (bool): Override Jupyter auto-detection.
#     options (dict): Visualiser-specific options, e.g. colors.
#     manual (bool): Don't parse `Doc` and instead expect a dict/list of dicts.
#     RETURNS (unicode): Rendered HTML markup.
#
#     DOCS: https://spacy.io/api/top-level#displacy.render
#     USAGE: https://spacy.io/usage/visualizers

# %%
from spacy import displacy

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Save $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  ONE
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Downy Liquid Fabric
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Conditioner
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     72
# ...

# %%
for t in doc:
    if t.lower_ in ['Save']:
        print(t)

# %%
for t in doc:
    print(t, t.pos_, t.dep_)
# Out:
# Save VERB ROOT
# $ SYM nmod
# 2.00 NUM dobj
# ONE NUM npadvmod
# Downy PROPN nmod
# Liquid PROPN compound
# Fabric PROPN nmod
# Conditioner PROPN appos
# 72 NUM nummod
# ld PROPN appos
# or CCONJ cc
# larger ADJ conj
# ( PUNCT punct
# includes VERB parataxis
# Downy PROPN compound
# Odor PROPN compound
# Protect PROPN dobj
# 48 NUM nummod
# oz NOUN dobj
# or CCONJ cc
# larger ADJ conj
# OR CCONJ nmod
# Downy PROPN nmod
# Wrinkle PROPN compound
# Guard PROPN conj
# 40 NUM nummod
# oz NOUN npadvmod
# or CCONJ cc
# larger ADJ conj
# OR CCONJ compound
# Downy PROPN appos
# Nature PROPN compound
# Blends PROPN conj
# 67 NUM nummod
# oz NOUN dobj
# or CCONJ cc
# larger ADJ conj
# ) PUNCT punct
# OR CCONJ nmod
# Bounce PROPN nmod
# / SYM punct
# Downy PROPN compound
# Sheets PROPN ROOT
# 130 NUM nummod
# ct NOUN appos
# or CCONJ cc
# larger ADJ conj
# ( PUNCT punct
# includes VERB ROOT
# Bounce PROPN nmod
# / SYM punct
# Downy PROPN nmod
# Wrinkle PROPN compound
# Guard PROPN dobj
# ...

# %%
for t in doc:
    print(t, t.lower_, t.pos_)
# Out:
# Save save VERB
# $ $ SYM
# 2.00 2.00 NUM
# ONE one NUM
# Downy downy PROPN
# Liquid liquid PROPN
# Fabric fabric PROPN
# Conditioner conditioner PROPN
# 72 72 NUM
# ld ld PROPN
# or or CCONJ
# larger larger ADJ
# ( ( PUNCT
# includes includes VERB
# Downy downy PROPN
# Odor odor PROPN
# Protect protect PROPN
# 48 48 NUM
# oz oz NOUN
# or or CCONJ
# larger larger ADJ
# OR or CCONJ
# Downy downy PROPN
# Wrinkle wrinkle PROPN
# Guard guard PROPN
# 40 40 NUM
# oz oz NOUN
# or or CCONJ
# larger larger ADJ
# OR or CCONJ
# Downy downy PROPN
# Nature nature PROPN
# Blends blends PROPN
# 67 67 NUM
# oz oz NOUN
# or or CCONJ
# larger larger ADJ
# ) ) PUNCT
# OR or CCONJ
# Bounce bounce PROPN
# / / SYM
# Downy downy PROPN
# Sheets sheets PROPN
# 130 130 NUM
# ct ct NOUN
# or or CCONJ
# larger larger ADJ
# ( ( PUNCT
# includes includes VERB
# Bounce bounce PROPN
# / / SYM
# Downy downy PROPN
# Wrinkle wrinkle PROPN
# Guard guard PROPN
# 80 80 NUM
# ct ct NOUN
# or or CCONJ
# larger larger ADJ
# ...

# %%
help(ent)
# Out:
# Help on Span object:
#
# class Span(builtins.object)
#  |  A slice from a Doc object.
#  |
#  |  DOCS: https://spacy.io/api/span
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(...)
#  |      Get a `Token` or a `Span` object
#  |
#  |      i (int or tuple): The index of the token within the span, or slice of
#  |          the span to get.
#  |      RETURNS (Token or Span): The token at `span[i]`.
#  |
#  |      DOCS: https://spacy.io/api/span#getitem
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(...)
#  |      Iterate over `Token` objects.
#  |
#  |      YIELDS (Token): A `Token` object.
#  |
#  |      DOCS: https://spacy.io/api/span#iter
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(...)
# ...

# %%
import nltk

# %%
sentence = "At eight o'clock on Thursday morning... Arthur didn't feel very good."
tokens = nltk.word_tokenize(sentence)

tagged = nltk.pos_tag(tokens)
tagged[0:6]
# Out:
# [('At', 'IN'),
#  ('eight', 'CD'),
#  ("o'clock", 'NN'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('morning', 'NN')]

# %%
#nltk.download('averaged_perceptron_tagger')
#nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Atishay\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Anaconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     819                 raise LookupError
#     820
# --> 821             with open(out_path, 'rb') as sr:
#     822                 res = sr.read()
#     823             os.remove(in_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Atishay\\AppData\\Local\\Temp\\tmp4i1f2otm.png'
# ...

# %%
from nltk.corpus import treebank
t = treebank.parsed_sents('wsj_0001.mrg')[0]
t.draw()
